# %% [markdown]
# # 🏦 Phase 2 — Attijari Bank : Analyse NLP des Logs
# ### Détection d'opportunités d'amélioration continue par Machine Learning
# ---

# %% [markdown]
# ---
# ##  CELLULE 1 — Installation des dépendances
# ---

# %%
import pandas as pd
import numpy as np
import json
import warnings
import spacy
warnings.filterwarnings('ignore')

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import LabelEncoder

nlp = spacy.load("fr_core_news_md")

print("✅ spaCy chargé :", spacy.__version__)
print("✅ Modèle :", nlp.meta['name'])
# Out:
# ✅ spaCy chargé : 3.8.14
# ✅ Modèle : core_news_md

# %% [markdown]
# ---
# ##  CELLULE 2 — Chargement et prétraitement NLP
# ---

# %%
df = pd.read_csv('attijari_bank_logs_10000.csv', sep=';')
df['timestamp']        = pd.to_datetime(df['timestamp'])
df['success']          = df['success'].astype(str).str.strip().map({'True': True, 'False': False})
df['duree_action_sec'] = pd.to_numeric(df['duree_action_sec'], errors='coerce').fillna(0.0)
df['error_code']       = df['error_code'].fillna('NONE')
df['field_modified']   = df['field_modified'].fillna('NONE')
df['heure']            = df['timestamp'].dt.hour
df['jour_semaine']     = df['timestamp'].dt.dayofweek
df['mois']             = df['timestamp'].dt.month

print('=' * 55)
print('  Informations générales')
print('=' * 55)
print(f'  Logs chargés       : {len(df):,}')
print(f'  Période            : {df["timestamp"].min().date()} → {df["timestamp"].max().date()}')
print(f'  Taux d\'échec       : {(~df["success"]).mean()*100:.1f}%')
print(f'  Utilisateurs       : {df["user_id"].nunique()}')
print(f'  Agences            : {df["agence"].nunique()}')
print(f'  Applications       : {df["application"].nunique()}')
print(f'  Processus          : {df["processus"].nunique()}')
print(f'  Actions distinctes : {df["action"].nunique()}')

# ── Construction du texte brut
df['log_text_brut'] = df.apply(lambda r:
    f"action {r['action'].lower().replace('_', ' ')} "
    f"processus {r['processus'].lower().replace('_', ' ')} "
    f"application {r['application'].lower().replace('_', ' ')} "
    f"agence {r['agence'].lower().replace('_', ' ')} "
    f"erreur {r['error_code'].lower().replace('_', ' ')} "
    f"duree {int(r['duree_action_sec'])} secondes "
    f"{'echec' if not r['success'] else 'succes'}",
    axis=1
)

# ── Lemmatisation spaCy
print('\n⏳ Lemmatisation en cours (spaCy)...')
texts       = df['log_text_brut'].tolist()
lemmes_list = []
batch_size  = 500

for i in range(0, len(texts), batch_size):
    batch = texts[i:i+batch_size]
    docs  = list(nlp.pipe(batch, disable=['ner', 'parser']))
    for doc in docs:
        lemmes = [
            token.lemma_.lower()
            for token in doc
            if not token.is_stop and not token.is_punct
            and not token.is_space and len(token.text) > 2
        ]
        lemmes_list.append(' '.join(lemmes))
    if (i // batch_size) % 5 == 0:
        print(f'  Traité {min(i+batch_size, len(texts))}/{len(texts)} logs...')

df['log_text_lemme'] = lemmes_list
print('✅ Lemmatisation terminée.')
print('\n📖 Exemple NLP :')
print('  AVANT :', df['log_text_brut'].iloc[0])
print('  APRÈS :', df['log_text_lemme'].iloc[0])
# Out:
# ...
#   Informations générales
# ...
#   Logs chargés       : 10,000
#   Période            : 2025-01-01 → 2026-02-05
#   Taux d'échec       : 25.2%
#   Utilisateurs       : 80
#   Agences            : 10
#   Applications       : 4
#   Processus          : 10
#   Actions distinctes : 12
#
# ⏳ Lemmatisation en cours (spaCy)...
#   Traité 500/10000 logs...
#   Traité 3000/10000 logs...
#   Traité 5500/10000 logs...
#   Traité 8000/10000 logs...
# ✅ Lemmatisation terminée.
#
# 📖 Exemple NLP :
#   AVANT : action login processus demande credit conso application attijari net agence agence tunis centre erreur none duree 4 secondes succes
#   APRÈS : action login processu demande credit consommation application attijari net agence agence tuni centr erreur none duree seconde succe

# %% [markdown]
# ---
# ##  CELLULE 3 — TF-IDF + KMeans + Affichage des clusters
# ---

# %%
# ── TF-IDF
vectorizer = TfidfVectorizer(max_features=100, ngram_range=(1, 2), min_df=2, max_df=0.95)
X_tfidf    = vectorizer.fit_transform(df['log_text_lemme'])

# ── KMeans k=8
kmeans        = KMeans(n_clusters=8, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X_tfidf)

# ── Tableau récapitulatif des clusters
print('=' * 75)
print('   Clusters sémantiques — KMeans (k=8)')
print('=' * 75)

clusters_rows = []
for c in range(8):
    s          = df[df['cluster'] == c]
    nb         = len(s)
    taux_echec = round((~s['success']).mean() * 100, 1)
    duree_moy  = round(s['duree_action_sec'].mean(), 1)
    top_action = s['action'].value_counts().index[0]
    top_proc   = s['processus'].value_counts().index[0]
    top3       = ' | '.join([f"{k}({v})" for k, v in s['action'].value_counts().head(3).items()])
    clusters_rows.append({
        'Cluster'          : c,
        'Logs'             : nb,
        'Taux échec (%)'   : taux_echec,
        'Durée moy (s)'    : duree_moy,
        'Action dominante' : top_action,
        'Processus dominant': top_proc
    })

df_clusters = pd.DataFrame(clusters_rows).set_index('Cluster')
print(df_clusters.to_string())

print('\n  Détail Top 3 actions par cluster :')
print('─' * 75)
for c in range(8):
    s    = df[df['cluster'] == c]
    top3 = ' | '.join([f"{k} ({v})" for k, v in s['action'].value_counts().head(3).items()])
    print(f'  Cluster {c} ({len(s):4d} logs) : {top3}')

print(f'\n {len(df):,} logs répartis en 8 clusters')
# Out:
# ...
#    Clusters sémantiques — KMeans (k=8)
# ...
#          Logs  Taux échec (%)  Durée moy (s)  Action dominante            Processus dominant
# Cluster
# 0         981            27.1            6.4  ERROR_VALIDATION  OUVERTURE_COMPTE_PARTICULIER
# 1        1006            26.2            6.3     ACCESS_DENIED              DEMANDE_CHEQUIER
# 2         988            23.9            6.4            REJECT              OPPOSITION_CARTE
# 3        1027            24.5            6.7         OPEN_FORM            DEMANDE_CARTE_VISA
# 4        1004            24.4            6.8            LOGOUT                CHANGE_DEVISES
# 5        1028            25.3            6.5            LOGOUT          DEMANDE_CREDIT_CONSO
# 6        1991            24.9            6.7             LOGIN              VIREMENT_INTERNE
# 7        1975            25.2            6.3     ACCESS_DENIED        PAIEMENT_FACTURE_SONED
#
#   Détail Top 3 actions par cluster :
# ...

# %% [markdown]
# ---
# ##  CELLULE 4 — Détection multi-modules (Répétitions + Erreurs + Goulots)
# ---

# %%
# ── MODULE 3 : Répétitions
repetitions = []
for action in ['SESSION_EXPIRED', 'ERROR_VALIDATION']:
    g = df[df['action'] == action].groupby(['user_id', 'processus']).size().reset_index(name='nb')
    for _, r in g[g['nb'] >= 3].iterrows():
        repetitions.append({
            'type'              : f'REPETITION_{action}',
            'user_id'           : r['user_id'],
            'processus'         : r['processus'],
            'nb_occurrences'    : int(r['nb']),
            'impact'            : 'HAUT' if r['nb'] >= 5 else 'MOYEN',
            'cout_estime_tnd'   : round(r['nb'] * 2 * 0.5, 2),
            'action_corrective' : 'Reconnexion automatique via RPA'
        })

fill = df[df['action'] == 'FILL_FIELD'].groupby(['user_id', 'processus', 'field_modified']).size().reset_index(name='nb')
for _, r in fill[fill['nb'] >= 4].iterrows():
    repetitions.append({
        'type'              : 'REPETITION_FILL_FIELD',
        'user_id'           : r['user_id'],
        'processus'         : r['processus'],
        'field'             : r['field_modified'],
        'nb_occurrences'    : int(r['nb']),
        'impact'            : 'MOYEN',
        'cout_estime_tnd'   : round(r['nb'] * 1.5 * 0.5, 2),
        'action_corrective' : 'Pré-remplir automatiquement via RPA'
    })

print('=' * 55)
print('  MODULE 3 — Répétitions')
print('=' * 55)
print(f'  Total : {len(repetitions)}')
for t, nb in pd.Series([r['type'] for r in repetitions]).value_counts().items():
    print(f'  {t:35s} : {nb}')
print('  Top 5 :')
for r in sorted(repetitions, key=lambda x: x['nb_occurrences'], reverse=True)[:5]:
    print(f"    {r['type']:35s} | {r['user_id']} | {r['processus']:25s} | {r['nb_occurrences']}x")

# ── MODULE 4 : Erreurs
descriptions = {
    'ERR_001':'Timeout connexion',       'ERR_101':'Erreur validation formulaire',
    'ERR_201':'Session expirée',         'ERR_301':'Données manquantes',
    'ERR_401':'Accès non autorisé',      'ERR_501':'Erreur serveur interne',
    'ERR_601':'Données dupliquées',      'ERR_701':'Erreur réseau',
    'ERR_901':'Erreur permission'
}
corrections = {
    'ERR_001':'Optimiser timeouts',      'ERR_101':'Améliorer validation client',
    'ERR_201':'Refresh session (RPA)',   'ERR_301':'Contrôles de saisie',
    'ERR_401':'Revoir droits accès',     'ERR_501':'Monitoring serveur',
    'ERR_601':'Détection doublons',      'ERR_701':'Retry réseau auto',
    'ERR_901':'Réviser permissions'
}
cout_erreur = {
    'ERR_001':3.0,'ERR_101':1.5,'ERR_201':2.0,'ERR_301':1.0,
    'ERR_401':5.0,'ERR_501':8.0,'ERR_601':2.5,'ERR_701':1.5,'ERR_901':4.0
}

erreurs = []
grp = (df[df['error_code'] != 'NONE']
       .groupby(['error_code','processus','application'])
       .size().reset_index(name='nb')
       .query('nb >= 5')
       .sort_values('nb', ascending=False))
for _, r in grp.iterrows():
    cout = cout_erreur.get(r['error_code'], 2.0) * r['nb']
    erreurs.append({
        'type'              : 'ERREUR_FREQUENTE',
        'error_code'        : r['error_code'],
        'description'       : descriptions.get(r['error_code'], 'Inconnue'),
        'processus'         : r['processus'],
        'application'       : r['application'],
        'nb_occurrences'    : int(r['nb']),
        'impact'            : 'CRITIQUE' if r['nb']>=20 else 'HAUT' if r['nb']>=10 else 'MOYEN',
        'cout_estime_tnd'   : round(cout, 2),
        'action_corrective' : corrections.get(r['error_code'], 'Analyser logs détaillés')
    })

print('\n' + '=' * 55)
print('  MODULE 4 — Erreurs fréquentes')
print('=' * 55)
print(f'  Total : {len(erreurs)}')
print('  Top 5 :')
for e in sorted(erreurs, key=lambda x: x['nb_occurrences'], reverse=True)[:5]:
    print(f"    {e['error_code']} | {e['processus']:28s} | {e['nb_occurrences']:3d}x | {e['impact']:8s} | {e['cout_estime_tnd']} TND")

# ── MODULE 5 : Goulots
stats    = df.groupby(['processus','action'])['duree_action_sec'].agg(['mean','std']).reset_index()
stats['seuil'] = stats['mean'] + 2 * stats['std'].fillna(0)
df_lents = df.merge(stats, on=['processus','action'])
df_lents = df_lents[df_lents['duree_action_sec'] > df_lents['seuil']]

goulots = []
grp_g   = (df_lents.groupby(['processus','action'])
            .agg(nb=('duree_action_sec','count'),moy=('duree_action_sec','mean'),mx=('duree_action_sec','max'))
            .reset_index().query('nb >= 3').sort_values('moy', ascending=False))
for _, r in grp_g.iterrows():
    surplus_min = r['nb'] * (r['moy'] - stats.loc[
        (stats['processus']==r['processus']) & (stats['action']==r['action']),'mean'
    ].values[0]) / 60
    goulots.append({
        'type'              : 'GOULOT_ETRANGLEMENT',
        'processus'         : r['processus'],
        'action'            : r['action'],
        'nb_occurrences'    : int(r['nb']),
        'duree_moy_sec'     : round(float(r['moy']),2),
        'duree_max_sec'     : round(float(r['mx']),2),
        'impact'            : 'HAUT' if r['moy']>15 else 'MOYEN',
        'temps_perdu_min'   : round(float(surplus_min),2),
        'cout_estime_tnd'   : round(float(surplus_min)*0.5,2),
        'action_corrective' : f"Automatiser {r['action']} via RPA"
    })

print('\n' + '=' * 55)
print('  MODULE 5 — Goulots d\'étranglement')
print('=' * 55)
print(f'  Total : {len(goulots)}')
print('  Top 5 :')
for g in goulots[:5]:
    print(f"    {g['action']:20s} | {g['processus']:25s} | moy: {g['duree_moy_sec']:5.1f}s | {g['cout_estime_tnd']} TND")
# Out:
# ...
#   MODULE 3 — Répétitions
# ...
#   Total : 146
#   REPETITION_ERROR_VALIDATION         : 77
#   REPETITION_SESSION_EXPIRED          : 69
#   Top 5 :
#     REPETITION_ERROR_VALIDATION         | USER0022 | VIREMENT_INTERNATIONAL    | 6x
#     REPETITION_ERROR_VALIDATION         | USER0002 | OPPOSITION_CARTE          | 5x
#     REPETITION_ERROR_VALIDATION         | USER0004 | PAIEMENT_FACTURE_SONED    | 5x
#     REPETITION_ERROR_VALIDATION         | USER0079 | OPPOSITION_CARTE          | 5x
#     REPETITION_SESSION_EXPIRED          | USER0003 | VIREMENT_INTERNE          | 4x
#
# ...
#   MODULE 4 — Erreurs fréquentes
# ...
#   Total : 304
#   Top 5 :
#     ERR_301 | PAIEMENT_FACTURE_SONED       |  15x | HAUT     | 15.0 TND
#     ERR_201 | DEMANDE_CREDIT_CONSO         |  14x | HAUT     | 28.0 TND
#     ERR_301 | CHANGE_DEVISES               |  13x | HAUT     | 13.0 TND
#     ERR_501 | DEMANDE_CREDIT_CONSO         |  13x | HAUT     | 104.0 TND
# ...

# %% [markdown]
# ---
# ##  CELLULE 5 — Isolation Forest (Anomalies ML)
# ---

# %%
df_ml = df.copy()
for col in ['action','processus','application','agence']:
    df_ml[col+'_enc'] = LabelEncoder().fit_transform(df_ml[col])
df_ml['suc'] = df_ml['success'].astype(int)

feats = ['action_enc','processus_enc','application_enc','agence_enc',
         'duree_action_sec','suc','heure','jour_semaine']

iso            = IsolationForest(contamination=0.05, random_state=42, n_estimators=100)
df_ml['anom']  = iso.fit_predict(df_ml[feats].values)
df_ml['score'] = iso.decision_function(df_ml[feats].values)

df_anom   = df_ml[df_ml['anom'] == -1]
anomalies = []
for _, r in df_anom.iterrows():
    anomalies.append({
        'type'              : 'ANOMALIE_COMPORTEMENTALE',
        'user_id'           : r['user_id'],
        'agence'            : r['agence'],
        'processus'         : r['processus'],
        'action'            : r['action'],
        'duree_sec'         : round(float(r['duree_action_sec']),2),
        'success'           : bool(r['success']),
        'error_code'        : r['error_code'],
        'score_anomalie'    : round(float(r['score']),4),
        'impact'            : 'CRITIQUE' if r['score']<-0.2 else 'HAUT',
        'cout_estime_tnd'   : round(abs(float(r['score']))*10,2),
        'action_corrective' : 'Alerter le superviseur et vérifier manuellement'
    })

print('=' * 55)
print('  MODULE 6 — Anomalies ML (Isolation Forest 5%)')
print('=' * 55)
print(f'  Total anomalies  : {len(anomalies)} ({len(anomalies)/len(df)*100:.1f}%)')
print(f'  Impact CRITIQUE  : {len([a for a in anomalies if a["impact"]=="CRITIQUE"])}')
print(f'  Impact HAUT      : {len([a for a in anomalies if a["impact"]=="HAUT"])}')
print('\n  Top 5 utilisateurs anormaux :')
for user, nb in df_anom['user_id'].value_counts().head(5).items():
    print(f'    {user} → {nb} anomalies')
print('\n  Top 5 agences anormales :')
for agence, nb in df_anom['agence'].value_counts().head(5).items():
    print(f'    {agence} → {nb} anomalies')
# Out:
# ...
#   MODULE 6 — Anomalies ML (Isolation Forest 5%)
# ...
#   Total anomalies  : 500 (5.0%)
#   Impact CRITIQUE  : 0
#   Impact HAUT      : 500
#
#   Top 5 utilisateurs anormaux :
#     USER0008 → 11 anomalies
#     USER0073 → 11 anomalies
#     USER0077 → 11 anomalies
#     USER0050 → 11 anomalies
#     USER0058 → 11 anomalies
#
#   Top 5 agences anormales :
#     AGENCE TUNIS CENTRE → 107 anomalies
#     AGENCE BIZERTE → 91 anomalies
#     AGENCE SOUSSE → 69 anomalies
#     AGENCE CARTHAGE → 51 anomalies
#     AGENCE SFAX → 45 anomalies

# %% [markdown]
# ---
# ##  CELLULE 6 — Scoring multi-critères + Export JSON
# ---

# %%
def score_priorite(frequence, temps_min, cout_tnd, poids_freq=0.3, poids_temps=0.3, poids_cout=0.4):
    score_freq  = min(frequence/50,  1.0) * 100
    score_temps = min(temps_min/30,  1.0) * 100
    score_cout  = min(cout_tnd/100,  1.0) * 100
    return round(poids_freq*score_freq + poids_temps*score_temps + poids_cout*score_cout, 1)

opportunites = []

for r in repetitions:
    freq, temps, cout = r['nb_occurrences'], r['nb_occurrences']*2, r.get('cout_estime_tnd', r['nb_occurrences']*1)
    score = score_priorite(freq, temps, cout)
    if freq >= 5:
        opportunites.append({
            'categorie'       : 'AUTOMATISATION_RPA',
            'priorite'        : 1 if score >= 60 else 2,
            'score_composite' : score,
            'titre'           : f"Reconnexion auto {r['user_id']} sur {r['processus']}",
            'robot_rpa'       : 'RobotReconnexionAuto',
            'nb_occurrences'  : freq,
            'gain_temps_min'  : temps,
            'gain_cout_tnd'   : cout,
            'roi_estime'      : f"{round(cout*12, 0)} TND/an"
        })

for e in erreurs:
    freq, temps, cout = e['nb_occurrences'], e['nb_occurrences']*3, e.get('cout_estime_tnd', e['nb_occurrences']*2)
    score = score_priorite(freq, temps, cout)
    if freq >= 15:
        opportunites.append({
            'categorie'       : 'CORRECTION_PROACTIVE',
            'priorite'        : 1 if score >= 60 else 2,
            'score_composite' : score,
            'titre'           : f"Auto-correction {e['error_code']} sur {e['processus']}",
            'robot_rpa'       : f"RobotCorrection_{e['error_code']}",
            'nb_occurrences'  : freq,
            'gain_temps_min'  : temps,
            'gain_cout_tnd'   : cout,
            'roi_estime'      : f"{round(cout*12, 0)} TND/an"
        })

for g in goulots:
    freq  = g['nb_occurrences']
    temps = g.get('temps_perdu_min', freq * g['duree_moy_sec'] / 60)
    cout  = g.get('cout_estime_tnd', temps * 0.5)
    score = score_priorite(freq, temps, cout)
    if g['duree_moy_sec'] > 12:
        opportunites.append({
            'categorie'       : 'OPTIMISATION_PROCESSUS',
            'priorite'        : 2 if score >= 40 else 3,
            'score_composite' : score,
            'titre'           : f"Optimiser {g['action']} sur {g['processus']}",
            'robot_rpa'       : f"RobotOptimise_{g['action']}",
            'nb_occurrences'  : freq,
            'gain_temps_min'  : round(temps,1),
            'gain_cout_tnd'   : round(cout,2),
            'roi_estime'      : f"{round(cout*12, 0)} TND/an"
        })

opportunites.sort(key=lambda x: x['score_composite'], reverse=True)

# ── Export JSON
resultats = {
    'repetitions'  : repetitions,
    'erreurs'      : erreurs,
    'goulots'      : goulots,
    'anomalies'    : anomalies,
    'opportunites' : opportunites
}
with open('resultats_phase2.json', 'w', encoding='utf-8') as f:
    json.dump(resultats, f, ensure_ascii=False, indent=2)

print(f"""
{'='*60}
  RAPPORT FINAL — Phase 2
  Logs analysés         : {len(df):,}
  Taux d'échec          : {(~df['success']).mean()*100:.1f}%
  Clusters sémantiques  : 8
  Répétitions           : {len(repetitions)}
  Erreurs fréquentes    : {len(erreurs)}
  Goulots               : {len(goulots)}
  Anomalies ML          : {len(anomalies)}
  Opportunités RPA      : {len(opportunites)}
  Gain temps estimé     : {sum(o.get('gain_temps_min',0) for o in opportunites):.0f} minutes
  Gain coût estimé      : {sum(o.get('gain_cout_tnd',0) for o in opportunites):.0f} TND
{'='*60}
✅ resultats_phase2.json sauvegardé""")
# Out:
# ...
#   RAPPORT FINAL — Phase 2
#   Logs analysés         : 10,000
#   Taux d'échec          : 25.2%
#   Clusters sémantiques  : 8
#   Répétitions           : 146
#   Erreurs fréquentes    : 304
#   Goulots               : 112
#   Anomalies ML          : 500
#   Opportunités RPA      : 117
#   Gain temps estimé     : 245 minutes
#   Gain coût estimé      : 115 TND
# ...
# ✅ resultats_phase2.json sauvegardé

# %% [markdown]
# ---
# ##  CELLULE 7 — Affichage du fichier resultats_phase2.json
# ---

# %%
with open('resultats_phase2.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# ── Résumé général
print('=' * 60)
print('   resultats_phase2.json — Contenu')
print('=' * 60)
for cle, val in data.items():
    print(f'  {cle:15s} : {len(val):4d} entrées')

# ── Top 3 Répétitions
print('\n' + '─' * 60)
print('   TOP 3 RÉPÉTITIONS')
print('─' * 60)
df_rep = pd.DataFrame(data['repetitions'])
if len(df_rep) > 0:
    cols = [c for c in ['type','user_id','processus','nb_occurrences','impact'] if c in df_rep.columns]
    print(df_rep.nlargest(3, 'nb_occurrences')[cols].to_string(index=False))

# ── Top 3 Erreurs
print('\n' + '─' * 60)
print('    TOP 3 ERREURS FRÉQUENTES')
print('─' * 60)
df_err = pd.DataFrame(data['erreurs'])
if len(df_err) > 0:
    cols = [c for c in ['error_code','processus','nb_occurrences','impact','cout_estime_tnd'] if c in df_err.columns]
    print(df_err.nlargest(3, 'nb_occurrences')[cols].to_string(index=False))

# ── Top 3 Goulots
print('\n' + '─' * 60)
print('    TOP 3 GOULOTS D\'ÉTRANGLEMENT')
print('─' * 60)
df_gou = pd.DataFrame(data['goulots'])
if len(df_gou) > 0:
    cols = [c for c in ['action','processus','duree_moy_sec','nb_occurrences','impact'] if c in df_gou.columns]
    print(df_gou.nlargest(3, 'duree_moy_sec')[cols].to_string(index=False))

# ── Top 3 Opportunités
print('\n' + '─' * 60)
print('   TOP 3 OPPORTUNITÉS RPA (par score composite)')
print('─' * 60)
df_opp = pd.DataFrame(data['opportunites'])
if len(df_opp) > 0:
    cols = [c for c in ['categorie','titre','score_composite','gain_temps_min','gain_cout_tnd','roi_estime'] if c in df_opp.columns]
    print(df_opp.nlargest(3, 'score_composite')[cols].to_string(index=False))

# ── Aperçu JSON brut
print('\n' + '─' * 60)
print('   Aperçu JSON brut (3 premières opportunités)')
print('─' * 60)
print(json.dumps({'opportunites': data['opportunites'][:3]}, ensure_ascii=False, indent=2))
# Out:
# ...
#    resultats_phase2.json — Contenu
# ...
#   repetitions     :  146 entrées
#   erreurs         :  304 entrées
#   goulots         :  112 entrées
#   anomalies       :  500 entrées
#   opportunites    :  117 entrées
#
# ────────────────────────────────────────────────────────────
#    TOP 3 RÉPÉTITIONS
# ────────────────────────────────────────────────────────────
#                        type  user_id              processus  nb_occurrences impact
# REPETITION_ERROR_VALIDATION USER0022 VIREMENT_INTERNATIONAL               6   HAUT
# REPETITION_ERROR_VALIDATION USER0002       OPPOSITION_CARTE               5   HAUT
# REPETITION_ERROR_VALIDATION USER0004 PAIEMENT_FACTURE_SONED               5   HAUT
#
# ────────────────────────────────────────────────────────────
#     TOP 3 ERREURS FRÉQUENTES
# ────────────────────────────────────────────────────────────
# error_code              processus  nb_occurrences impact  cout_estime_tnd
# ...
